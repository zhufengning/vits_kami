# %%
# %cd /kaggle/working

# %%
# !pwd
# !git clone https://github.com/zhufengning/vits_kami

# %%
# %cd vits_kami
# !pip install -r requirements.txt

# %%
# !cp /kaggle/input/kami-voice/kami . -r
# !mkdir logs
# !mkdir logs/ljs_base
# !cp /kaggle/input/kami-checkpoint1/* logs/ljs_base
# !ls kami

# %%
# !pip install unidecode pypinyin pypinyin_dict 
# !apt install espeak -y

# %%
# %cd monotonic_align
# !python setup.py build_ext --inplace
# %cd ..

# %%
# !python preprocess.py --text_index 1 --filelists filelists/kami.txt --text_cleaners=chinese_cleaners2

# %%
# !python train.py -c configs/kami.json -m ljs_base
